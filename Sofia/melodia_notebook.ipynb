# %% [markdown]
# # Limpeza e tratamento dos dados

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %%
df=pd.read_csv("Base_Melodia.csv")
df.head()
# Out:
#         sort_name      clean_name                       album  rank_2003  \
# 0  Sinatra, Frank   Frank Sinatra      In the Wee Small Hours      100.0
# 1     Diddley, Bo      Bo Diddley  Bo Diddley / Go Bo Diddley      214.0
# 2  Presley, Elvis   Elvis Presley               Elvis Presley       55.0
# 3  Sinatra, Frank   Frank Sinatra  Songs for Swingin' Lovers!      306.0
# 4  Little Richard  Little Richard       Here's Little Richard       50.0
#
#    rank_2012  rank_2020  differential  release_year  \
# 0      101.0      282.0          -182          1955
# 1      216.0      455.0          -241          1955
# 2       56.0      332.0          -277          1956
# 3      308.0        NaN          -195          1956
# 4       50.0      227.0          -177          1957
#
#                          genre    type  weeks_on_billboard  \
# 0                Big Band/Jazz  Studio                14.0
# 1  Rock n' Roll/Rhythm & Blues  Studio                 NaN
# ...

# %%
df.describe()
# Out:
#         rank_2003   rank_2012   rank_2020  differential  release_year  \
# count  500.000000  500.000000  500.000000    691.000000    691.000000
# mean   250.504000  250.500000  250.500000    -12.322721   1982.872648
# std    144.486063  144.481833  144.481833    199.041031     14.554784
# min      1.000000    1.000000    1.000000   -501.000000   1955.000000
# 25%    125.750000  125.750000  125.750000   -137.500000   1971.000000
# 50%    250.500000  250.500000  250.500000     -8.000000   1979.000000
# 75%    375.250000  375.250000  375.250000    106.000000   1994.000000
# max    500.000000  500.000000  500.000000    484.000000   2019.000000
#
#        weeks_on_billboard  peak_billboard_position  spotify_popularity  \
# count          572.000000               691.000000          654.000000
# mean            64.270979                61.193922           55.805810
# std             75.141513                77.156551           14.948525
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 691 entries, 0 to 690
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   sort_name                 691 non-null    object
#  1   clean_name                691 non-null    object
#  2   album                     691 non-null    object
#  3   rank_2003                 500 non-null    float64
#  4   rank_2012                 500 non-null    float64
#  5   rank_2020                 500 non-null    float64
#  6   differential              691 non-null    int64
#  7   release_year              691 non-null    int64
#  8   genre                     527 non-null    object
#  9   type                      691 non-null    object
#  10  weeks_on_billboard        572 non-null    float64
#  11  peak_billboard_position   691 non-null    int64
#  12  spotify_popularity        654 non-null    float64
# ...

# %% [markdown]
# ### Entendendo as colunas

# %% [markdown]
# Clean_name: nome do artista
#
# Album: título do álbum
#
# Rank_2003: posição que o álbum ocupava no ranking de top 500 melhores álbums de todos os tempos da revista Rolling Stone em 2003
#
# Rank_2012: posição que o álbum ocupava no ranking de top 500 melhores álbuns de todos os tempos da revista Rolling Stone em 2012
#
# Rank_2020: posição que o álbum ocupava no ranking de top 500 melhores álbuns de todos os tempos da revista Rolling Stone em 2020
#
# Differential: a diferença entre o rank de 2003 e 2020, que é negativa se o álbum desceu de posição ao longo dos anos e positiva se subiu
#
# Release_year: ano em que o álbum foi lançado
#
# Genre: gênero musical do álbum
#
# Type: tipo de álbum, como um álbum de estúdio, uma compilação, ou um álbum ao vivo
#
# Weeks_on_billboard: número de semanas que o álbum passou na Billboard 200, que mede o desempenho dos álbuns em termos de vendas e popularidade
#
# Peak_billboard_position: posição mais alta que o álbum alcançou na Billboard 200, que indica o pico de popularidade do álbum
#
# Spotify_popularity: medida de popularidade do álbum na plataforma de streaming Spotify
#
# Artist_member_count: número de integrantes do grupo musical (para artistas solo, esse valor é 1)
#
# Artist_gender: gênero dos membros do grupo ou do artista solo
#
# Artist_birth_year_sum: soma dos anos de nascimento de todos os membros do grupo ou, no caso de um artista solo, o ano de nascimento desse artista (esse valor pode ser usado para calcular a idade média dos membros)
#
# Debut_album_release_year: ano em que o artista ou banda lançou seu álbum de estreia
#
# Ave_age_at_top_500: idade média dos membros do grupo (ou do artista solo) no momento em que o álbum incluído na lista de "Top 500" álbuns foi lançado
#
# Years_between: diferença entre o ano de lançamento do álbum de estreia do artista e o e o ano em que o álbum listado no "Top 500" foi lançado

# %% [markdown]
# ### Removendo colunas desnecessárias e incluindo uma coluna que pode ser interessante para a análise

# %%
df = df.drop("spotify_url",axis=1)
df = df.drop("album_id",axis=1)
df = df.drop("sort_name",axis=1)
df['ave_age'] = 2024 - (df['artist_birth_year_sum']/df['artist_member_count'])
df.head()
# Out:
#        clean_name                       album  rank_2003  rank_2012  \
# 0   Frank Sinatra      In the Wee Small Hours      100.0      101.0
# 1      Bo Diddley  Bo Diddley / Go Bo Diddley      214.0      216.0
# 2   Elvis Presley               Elvis Presley       55.0       56.0
# 3   Frank Sinatra  Songs for Swingin' Lovers!      306.0      308.0
# 4  Little Richard       Here's Little Richard       50.0       50.0
#
#    rank_2020  differential  release_year                        genre    type  \
# 0      282.0          -182          1955                Big Band/Jazz  Studio
# 1      455.0          -241          1955  Rock n' Roll/Rhythm & Blues  Studio
# 2      332.0          -277          1956  Rock n' Roll/Rhythm & Blues  Studio
# 3        NaN          -195          1956                Big Band/Jazz  Studio
# 4      227.0          -177          1957                          NaN  Studio
#
#    weeks_on_billboard  peak_billboard_position  spotify_popularity  \
# ...

# %% [markdown]
# ### Identificando os valores únicos para cada coluna

# %%
for col in df.columns:
  print(col.upper())
  print(df[col].unique(), df[col].dtype, "\n")
# Out:
# CLEAN_NAME
# ['Frank Sinatra' 'Bo Diddley' 'Elvis Presley' 'Little Richard' 'Beyonce'
#  'Amy Winehouse' 'Buddy Holly' 'Kate Bush' 'Miles Davis' 'John Coltrane'
#  'Ornette Coleman' 'Erykah Badu' 'Missy Elliott' "Howlin' Wolf"
#  'Taylor Swift' 'Fiona Apple' 'Ray Charles' 'Janet Jackson' 'Etta James'
#  'Joni Mitchell' 'Adele' 'Muddy Waters' 'Aretha Franklin' 'Robert Johnson'
#  'Sleater-Kinney' 'Bobby "Blue" Bland' 'Robyn' 'Sade' 'Bjork'
#  'Nina Simone' 'The Chicks' 'James Brown' 'Rihanna' 'Tori Amos'
#  'Bob Dylan' 'The Beatles' 'Phil Spector' 'Kacey Musgraves'
#  'Mary J. Blige' 'Alicia Keys' 'Donna Summer' 'The Ronettes'
#  "Destiny's Child" 'Shania Twain' 'Solange' 'PJ Harvey' 'Aaliyah'
#  'Rosalia' 'Billie Holiday' 'Lana Del Ray' 'Gillian Welch' 'Mariah Carey'
#  'Kelis' 'Diana Ross' 'Billie EIlish' 'The Raincoats' 'Getz & Gilberto'
#  'Anita Baker' 'M.I.A.' 'Lucinda Williams' 'Loretta Lynn' 'Britney Spears'
# ...

# %%
#Corrigindo erro de digitação
df['genre'] = df['genre'].replace({"Blues/Blues ROck": "Blues/Blues Rock"})

# %% [markdown]
# ### Valores nulos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 691 entries, 0 to 690
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   clean_name                691 non-null    object
#  1   album                     691 non-null    object
#  2   rank_2003                 500 non-null    float64
#  3   rank_2012                 500 non-null    float64
#  4   rank_2020                 500 non-null    float64
#  5   differential              691 non-null    int64
#  6   release_year              691 non-null    int64
#  7   genre                     527 non-null    object
#  8   type                      691 non-null    object
#  9   weeks_on_billboard        572 non-null    float64
#  10  peak_billboard_position   691 non-null    int64
#  11  spotify_popularity        654 non-null    float64
#  12  artist_member_count       686 non-null    float64
# ...

# %% [markdown]
# #### Semanas na Billboard 200

# %%
pd.set_option('display.max_rows', 700)
df['weeks_on_billboard'] = df['weeks_on_billboard'].fillna(0)
B = df.loc[df['weeks_on_billboard']==0]
B
# Out:
#                              clean_name  \
# 1                            Bo Diddley
# 3                         Frank Sinatra
# 7                           Buddy Holly
# 9                           Miles Davis
# 10                        John Coltrane
# 12                      Ornette Coleman
# 15                         Howlin' Wolf
# 18                          Ray Charles
# 20                           Etta James
# 23                         Muddy Waters
# 24                          Miles Davis
# 27                       Robert Johnson
# 28                       Sleater-Kinney
# 29                   Bobby "Blue" Bland
# 36                         Howlin' Wolf
# 44                         Phil Spector
# 51                         The Ronettes
# 57                              Rosalia
# 58                       Billie Holiday
# 62                         Muddy Waters
# 70                        The Raincoats
# 74                     Lucinda Williams
# ...

# %%
pd.set_option('display.max_rows', 40)
B = df.loc[df['peak_billboard_position']==201]
B
# Out:
#           clean_name                        album  rank_2003  rank_2012  \
# 1         Bo Diddley   Bo Diddley / Go Bo Diddley      214.0      216.0
# 7        Buddy Holly      The "Chirping" Crickets      421.0      420.0
# 9        Miles Davis                 Kind of Blue       12.0       12.0
# 10     John Coltrane                  Giant Steps      102.0      103.0
# 12   Ornette Coleman    The Shape of Jazz to Come      246.0      248.0
# ..               ...                          ...        ...        ...
# 664     Muddy Waters                The Anthology       38.0       38.0
# 675     Loretta Lynn       All Time Greatest Hits      485.0      478.0
# 685       Peter Wolf                    Sleepless      432.0      427.0
# 689        Manu Chao  Proxima estacion: Esperanza        NaN      474.0
# 690   The Beach Boys           The Smile Sessions        NaN      381.0
#
#      rank_2020  differential  release_year  \
# 1        455.0          -241          1955
# ...

# %% [markdown]
# ###### É possível concluir que '201' em 'peak_billboard_positon' representa que o álbum nunca ocupou uma posição na Billboard 200
#
# ###### Os únicos álbuns que ocuparam alguma posição na Billboard, mas não tiverem o número de semanas registrado foram "Songs for Swingin' Lovers!" e "The Genius of Ray Charles"

# %%
df = df.drop(3)
df = df.drop(18)
df
# Out:
#             clean_name                           album  rank_2003  rank_2012  \
# 0        Frank Sinatra          In the Wee Small Hours      100.0      101.0
# 1           Bo Diddley      Bo Diddley / Go Bo Diddley      214.0      216.0
# 2        Elvis Presley                   Elvis Presley       55.0       56.0
# 4       Little Richard           Here's Little Richard       50.0       50.0
# 5              Beyonce                        Lemonade        NaN        NaN
# ..                 ...                             ...        ...        ...
# 686               Beck                      Sea Change      440.0      436.0
# 687          Sam Cooke  Portrait of a Legend 1951-1964      106.0      107.0
# 688  The White Stripes                        Elephant      390.0      390.0
# 689          Manu Chao     Proxima estacion: Esperanza        NaN      474.0
# 690     The Beach Boys              The Smile Sessions        NaN      381.0
#
# ...

# %%
df_weeks = df[df['weeks_on_billboard'] != 0]

# %% [markdown]
# ### Número de membros

# %%
df['artist_member_count'] = df['artist_member_count'].fillna('Unknown')
C = df.loc[df['artist_member_count']=='Unknown']
C
# Out:
#           clean_name                                              album  \
# 499  Various Artists                  The Indestructible Beat of Soweto
# 579  Various Artists              The Best of the Girl Groups, Volume 1
# 621  Various Artists                         The Sun Records Collection
# 638  Various Artists                   Anthology of American Folk Music
# 646  Various Artists  Nuggets: Original Artyfacts From the First Psy...
#
#      rank_2003  rank_2012  rank_2020  differential  release_year  \
# 499        NaN      388.0      497.0             4          1985
# 579      422.0      421.0        NaN           -79          1990
# 621      308.0      311.0        NaN          -193          1994
# 638      276.0      278.0        NaN          -225          1997
# 646      196.0      196.0      405.0          -209          1998
#
#                                    genre         type  weeks_on_billboard  \
# ...

# %% [markdown]
# ##### Os mesmos cinco álbuns apresentam valores nulos em artist_member_count, artist_gender, artist_birth_year_sum, debut_album_release_year, ave_age_at_top_500, years_between e ave_age

# %%
df = df.dropna(subset=['artist_gender'])

# %% [markdown]
# #### Gênero musical

# %%
df['genre'] = df['genre'].fillna('Other')
df
# Out:
# C:\Users\sofia\AppData\Local\Temp\ipykernel_13532\2213840765.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['genre'] = df['genre'].fillna('Other')
#             clean_name                           album  rank_2003  rank_2012  \
# 0        Frank Sinatra          In the Wee Small Hours      100.0      101.0
# 1           Bo Diddley      Bo Diddley / Go Bo Diddley      214.0      216.0
# 2        Elvis Presley                   Elvis Presley       55.0       56.0
# 4       Little Richard           Here's Little Richard       50.0       50.0
# 5              Beyonce                        Lemonade        NaN        NaN
# ..                 ...                             ...        ...        ...
# ...

# %%
other_genre_albums = df[df['genre'] == 'Other']

# Agrupar por artista e calcular a soma da popularidade no Spotify
albuns_agrup = other_genre_albums.groupby('clean_name', as_index=False)['spotify_popularity'].sum()

# Ordenar pelos valores de 'spotify_popularity' em ordem decrescente
albuns_ordenados = albuns_agrup.sort_values(by='spotify_popularity', ascending=False)

# Exibir o resultado
display(albuns_ordenados)
# Out:
#         clean_name  spotify_popularity
# 69     The Beatles               664.0
# 14     David Bowie               403.0
# 52      Pink Floyd               269.0
# 68  The Beach Boys               235.0
# 71       The Byrds               220.0
# ..             ...                 ...
# 24     James Brown                 0.0
# 29   Joni Mitchell                 0.0
# 47    Otis Redding                 0.0
# 44    Neil Diamond                 0.0
# 45      Neil Young                 0.0
#
# [95 rows x 2 columns]

# %%
#identificando a qual gênero pertence cada artista

genre_mapping = {
    'The Beatles': 'Rock n\' Roll/Rhythm & Blues',
    'David Bowie': 'Rock n\' Roll/Rhythm & Blues',
    'Pink Floyd': 'Rock n\' Roll/Rhythm & Blues',
    'The Beach Boys': 'Rock n\' Roll/Rhythm & Blues',
    'The Byrds': 'Indie/Alternative Rock',
    'Prince': 'Rock n\' Roll/Rhythm & Blues',
    'Steely Dan': 'Rock n\' Roll/Rhythm & Blues',
    'Nick Drake': 'Indie/Alternative Rock',
    'Tom Petty': 'Rock n\' Roll/Rhythm & Blues',
    'Beyonce': 'Soul/Gospel/R&B',
    'Tom Waits': 'Singer-Songwriter/Heartland Rock',
    'The Who': 'Rock n\' Roll/Rhythm & Blues',
    'Jackson Browne': 'Rock n\' Roll/Rhythm & Blues',
    'John Lennon': 'Rock n\' Roll/Rhythm & Blues',
    'Madonna': 'Pop',
    'Van Morrison': 'Singer-Songwriter/Heartland Rock',
    'Paul Simon': 'Singer-Songwriter/Heartland Rock',
    'The Mamas and the Papas': 'Folk Rock',
    'Lou Reed': 'Indie/Alternative Rock',
    'Jefferson Airplane': 'Folk Rock',
    'The Kinks': 'Punk/Post-Punk/New Wave/Power Pop',
    'Bjork': 'Electronic',
    'Randy Newman': 'Singer-Songwriter/Heartland Rock',
    'Brian Eno': 'Electronic',
    'Mott the Hoople': 'Rock n\' Roll/Rhythm & Blues',
    'The Weeknd': 'Hip-Hop/Rap',
    'Lana Del Ray': 'Indie/Alternative Rock',
    'The Mothers of Invention': 'Rock n\' Roll/Rhythm & Blues',
    'Taylor Swift': 'Country/Folk/Country Rock/Folk Rock',
    'Lorde': 'Indie/Alternative Rock',
    'Tracey Chapman': 'Singer-Songwriter/Heartland Rock',
    'Weezer': 'Indie/Alternative Rock',
    'Kate Bush': 'Indie/Alternative Rock',
    'Britney Spears': 'Pop',
    'Destiny\'s Child': 'Soul/Gospel/R&B',
    'Jeff Buckley': 'Singer-Songwriter/Heartland Rock',
    'George Michael': 'Soul/Gospel/R&B',
    'Cocteau Twins': 'Indie/Alternative Rock',
    'Sinead O\'Connor': 'Soul/Gospel/R&B',
    'The Zombies': 'Rock n\' Roll/Rhythm & Blues',
    'James Taylor': 'Singer-Songwriter/Heartland Rock',
    'Paul McCartney': 'Rock n\' Roll/Rhythm & Blues',
    'Little Richard': 'Rock n\' Roll/Rhythm & Blues',
    'Richard & Linda Thompson': 'Folk Rock',
    'The Breeders': 'Indie/Alternative Rock',
    'Meat Loaf': 'Rock n\' Roll/Rhythm & Blues',
    'Rod Stewart': 'Rock n\' Roll/Rhythm & Blues',
    'Elliott Smith': 'Indie/Alternative Rock',
    'Depeche Mode': 'Electronic',
    'Harry Nilsson': 'Singer-Songwriter/Heartland Rock',
    'Yo La Tengo': 'Indie/Alternative Rock',
    'Linda Ronstadt': 'Folk Rock',
    'The Magnetic Fields': 'Indie/Alternative Rock',
    'Sheryl Crow': 'Singer-Songwriter/Heartland Rock',
    'DJ Shadow': 'Hip-Hop/Rap',
    'Simon & Garfunkel': 'Folk Rock',
    'The Carpenters': 'Pop',
    'Buffalo Springfield': 'Rock n\' Roll/Rhythm & Blues',
    'Todd Rundgren': 'Rock n\' Roll/Rhythm & Blues',
    'Minutemen': 'Punk/Post-Punk/New Wave/Power Pop',
    'Hank Williams': 'Country/Folk/Country Rock/Folk Rock',
    'Steve Earle': 'Country/Folk/Country Rock/Folk Rock',
    'Rihanna': 'Soul/Gospel/R&B',
    'ABBA': 'Pop',
    'Wilco': 'Indie/Alternative Rock',
    'Peter Gabriel': 'Rock n\' Roll/Rhythm & Blues',
    'Robert Johnson': 'Blues/Blues Rock',
    'Love': 'Rock n\' Roll/Rhythm & Blues',
    'Belle & Sebastian': 'Indie/Alternative Rock',
    'The Modern Lovers': 'Indie/Alternative Rock',
    'Sparks': 'Indie/Alternative Rock',
    'Wu-Tang Clan': 'Hip-Hop/Rap',
    'The Flying Burrito Brothers': 'Country/Folk/Country Rock/Folk Rock',
    'Can': 'Rock n\' Roll/Rhythm & Blues',
    'Queen': 'Rock n\' Roll/Rhythm & Blues',
    'Tori Amos': 'Singer-Songwriter/Heartland Rock',
    'Blood, Sweat & Tears': 'Rock n\' Roll/Rhythm & Blues',
    'Ian Dury and the Blockheads': 'Rock n\' Roll/Rhythm & Blues',
    'Boz Scaggs': 'Rock n\' Roll/Rhythm & Blues',
    'Brian Wilson': 'Rock n\' Roll/Rhythm & Blues',
    'War': 'Rock n\' Roll/Rhythm & Blues',
    'Moby Grape': 'Rock n\' Roll/Rhythm & Blues',
    'Yes': 'Rock n\' Roll/Rhythm & Blues',
    'Peter Wolf': 'Rock n\' Roll/Rhythm & Blues',
    'Laura Nyro': 'Singer-Songwriter/Heartland Rock',
    'Professor Longhair': 'Blues/Blues Rock',
    'Graham Parker': 'Rock n\' Roll/Rhythm & Blues',
    'Kelis': 'Hip-Hop/Rap',
    'The Pogues': 'Rock n\' Roll/Rhythm & Blues',
    'Captain Beefheart & His Magic Band': 'Rock n\' Roll/Rhythm & Blues',
    'James Brown': 'Soul/Gospel/R&B',
    'Joni Mitchell': 'Singer-Songwriter/Heartland Rock',
    'Otis Redding': 'Soul/Gospel/R&B',
    'Neil Diamond': 'Singer-Songwriter/Heartland Rock',
    'Neil Young': 'Singer-Songwriter/Heartland Rock'
}

df['genre'] = df['clean_name'].map(genre_mapping).fillna(df['genre'])

df[['clean_name', 'genre']].head()
# Out:
# C:\Users\sofia\AppData\Local\Temp\ipykernel_13532\2289122282.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['genre'] = df['clean_name'].map(genre_mapping).fillna(df['genre'])
#        clean_name                        genre
# 0   Frank Sinatra                Big Band/Jazz
# 1      Bo Diddley  Rock n' Roll/Rhythm & Blues
# 2   Elvis Presley  Rock n' Roll/Rhythm & Blues
# 4  Little Richard  Rock n' Roll/Rhythm & Blues
# 5         Beyonce              Soul/Gospel/R&B

# %% [markdown]
# ###### Conseguimos encaixar a maioria dos artistas nos gêneros já estabelecidos, no entanto a categoria 'Pop' precisou ser criada para artistas como Madonna e Abba

# %% [markdown]
# ##### Para rank_2002, rank_2012 e rank_2020, os valores nulos representam os álbuns que não foram incluídos nas respectivas listas de top 500 álbuns da Rolling Stone

# %%
#Para analisar os álbuns em relação à sua posição na lista da revista Rolling Stone nos três anos 
df_rank = df.dropna(subset=['rank_2003', 'rank_2012', 'rank_2020'])
df_rank
# Out:
#             clean_name                           album  rank_2003  rank_2012  \
# 0        Frank Sinatra          In the Wee Small Hours      100.0      101.0
# 1           Bo Diddley      Bo Diddley / Go Bo Diddley      214.0      216.0
# 2        Elvis Presley                   Elvis Presley       55.0       56.0
# 4       Little Richard           Here's Little Richard       50.0       50.0
# 9          Miles Davis                    Kind of Blue       12.0       12.0
# ..                 ...                             ...        ...        ...
# 664       Muddy Waters                   The Anthology       38.0       38.0
# 665               ABBA       The Definitive Collection      180.0      179.0
# 676           Coldplay     A Rush of Blood to the Head      473.0      466.0
# 687          Sam Cooke  Portrait of a Legend 1951-1964      106.0      107.0
# 688  The White Stripes                        Elephant      390.0      390.0
#
# ...

# %%
#Para analisar os álbuns em relação à sua posição na lista da revista Rolling Stone nos três anos separadamente
df_rank_2020 = df.dropna(subset=['rank_2020'])
df_rank_2012 = df.dropna(subset=['rank_2012'])
df_rank_2003 = df.dropna(subset=['rank_2003'])

# %% [markdown]
# #### A diferença entre o ranking de 2003 e de 2020 só pode ser analisada para os álbuns que possuem as duas informações

# %%
df_diff = df.dropna(subset=['rank_2003', 'rank_2020'])
df_diff
# Out:
#             clean_name                           album  rank_2003  rank_2012  \
# 0        Frank Sinatra          In the Wee Small Hours      100.0      101.0
# 1           Bo Diddley      Bo Diddley / Go Bo Diddley      214.0      216.0
# 2        Elvis Presley                   Elvis Presley       55.0       56.0
# 4       Little Richard           Here's Little Richard       50.0       50.0
# 9          Miles Davis                    Kind of Blue       12.0       12.0
# ..                 ...                             ...        ...        ...
# 664       Muddy Waters                   The Anthology       38.0       38.0
# 665               ABBA       The Definitive Collection      180.0      179.0
# 676           Coldplay     A Rush of Blood to the Head      473.0      466.0
# 687          Sam Cooke  Portrait of a Legend 1951-1964      106.0      107.0
# 688  The White Stripes                        Elephant      390.0      390.0
#
# ...

# %% [markdown]
# ### Popularidade no Spotify

# %%
#Para analisar os álbuns em relação à sua popularidade no spotify
dfS = df.dropna(subset=['spotify_popularity'])
dfS
# Out:
#             clean_name                           album  rank_2003  rank_2012  \
# 0        Frank Sinatra          In the Wee Small Hours      100.0      101.0
# 1           Bo Diddley      Bo Diddley / Go Bo Diddley      214.0      216.0
# 2        Elvis Presley                   Elvis Presley       55.0       56.0
# 4       Little Richard           Here's Little Richard       50.0       50.0
# 5              Beyonce                        Lemonade        NaN        NaN
# ..                 ...                             ...        ...        ...
# 686               Beck                      Sea Change      440.0      436.0
# 687          Sam Cooke  Portrait of a Legend 1951-1964      106.0      107.0
# 688  The White Stripes                        Elephant      390.0      390.0
# 689          Manu Chao     Proxima estacion: Esperanza        NaN      474.0
# 690     The Beach Boys              The Smile Sessions        NaN      381.0
#
# ...

# %% [markdown]
# # Desenvolvimento da análise

# %%
# Heatmap para observar correlações 

df_num = ['rank_2003','rank_2012','rank_2020','differential','release_year','weeks_on_billboard','peak_billboard_position','spotify_popularity','artist_member_count','artist_birth_year_sum','debut_album_release_year','ave_age_at_top_500','years_between']


sns.heatmap(df[df_num].corr(), 

annot=True,              
vmin=-1, vmax=1,           
cmap='winter')
# Out:
# <Axes: >

# %%
# Popularidade no Spotify por gênero musical 

plt.figure(figsize=(14, 10))

sns.boxplot(data=df, x='genre', y='spotify_popularity', palette='winter') 

plt.title('Popularidade no Spotify por Gênero Musical', fontsize=16, weight='bold')
plt.xlabel('Gênero', fontsize=12)
plt.ylabel('Popularidade no Spotify', fontsize=12)

plt.xticks(rotation=90)

plt.show()
# Out:
# C:\Users\sofia\AppData\Local\Temp\ipykernel_13532\2101538460.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='genre', y='spotify_popularity', palette='winter')

# %% [markdown]
# Utilizando boxplots para entender a distribuição de popularidade de cada gênero, observa-se que o gênero “latin” é o que possui a mediana de popularidade mais alta. Além disso, gêneros como Hip-Hop/Rap, Indie/Alternative Rock, Hard Rock/Metal e Pop também demonstram boa performance e consistência, de modo que são poucos os álbuns pouco populares quando comparados com os demais gêneros.

# %%
# Distribuição de gêneros
plt.figure(figsize=(10, 10))
sns.countplot(data=df, y='genre', palette='winter', order=df['genre'].value_counts().index)
plt.title('Distribuição de Gêneros Musicais', fontsize=20, weight = 'bold')
plt.xlabel('Número de álbuns no catálogo', fontsize=12)
plt.ylabel('Gênero', fontsize=12)
plt.yticks(rotation=0)
plt.show()
# Out:
# C:\Users\sofia\AppData\Local\Temp\ipykernel_13532\1092803892.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, y='genre', palette='winter', order=df['genre'].value_counts().index)

# %% [markdown]
# Punk / Post-Punk / New Wave/ Power Pop domina a quantidade de álbuns no catálogo, seguido por Soul / Gospel / R&B, Rock n' Roll/Rhythm & Blues, e Indie/Alternative Rock. Pensando em sua popularidade, é importante identificar quais dos gêneros já bem estabelecidos no catálogo tem maior potencial de vendas, de modo a priorizá-los. Afrobeat, Reggae, Pop e Latin são os gêneros com menor representação e dependendo da sua popularidade, poderia ser vantajoso expandir o catálogo nesses gêneros.

# %%
# Distribuição da diferença de posição nos Rankings (2003 - 2020)
plt.figure(figsize=(10, 6))

sns.histplot(df_diff["differential"], color=sns.color_palette('winter', as_cmap=True)(0.7), bins=20)


plt.title('Distribuição da diferença de posição nos Rankings (2003 - 2020)', fontsize=16, weight='bold')
plt.xlabel('Diferencial de Ranking', fontsize=12)
plt.ylabel('Frequência', fontsize=12)

plt.show()

# %% [markdown]
# Álbuns clássicos tendem a manter sua relevância
# Isso é interessante, pois pode-se ter maior segurança que álbuns que muito relevantes, como os que
# aparecem a lista de 500 melhores álbuns da Rolling Stone vão continuar sendo relevantes e, portanto,
# continuarão vendendo

# %%
# Diferença de tempo entre o lançamento do primeiro álbum e o álbum reconhecido no Top 500 por gênero
plt.figure(figsize=(12, 10))
sns.boxplot(data=df, x='genre', y='years_between', palette='winter')
plt.title('Diferença de tempo entre o lançamento do primeiro álbum e o álbum reconhecido no Top 500 por gênero', fontsize=16, weight='bold')
plt.xlabel('Gênero', fontsize=12)
plt.ylabel('Anos', fontsize=12)
plt.xticks(rotation=90, fontsize=10) 
plt.show()
# Out:
# C:\Users\sofia\AppData\Local\Temp\ipykernel_13532\4151825566.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='genre', y='years_between', palette='winter')

# %% [markdown]
# Alguns gêneros tendem a serem reconhecidos mais rapidamente, como Latin, Hip-Hop/Rap, Indie/Alternative Rock e Hard
# Rock/Metal e Punk/Post-Punk/New Wave/Power Pop

# %%
# Tipo de Álbum vs. Popularidade no Spotify
order = ["Studio", "Compilation", "Greatest Hits", "Live", "Soundtrack"]
df['type'] = pd.Categorical(df['type'], categories=order, ordered=True)
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='type', y='spotify_popularity', palette='winter')
plt.title('Tipo de Álbum vs. Popularidade no Spotify', fontsize=16, weight='bold')
plt.xlabel('Tipo de Álbum', fontsize=12)
plt.ylabel('Popularidade no Spotify', fontsize=12)
plt.xticks(rotation=45, fontsize=10)
plt.show()
# Out:
# C:\Users\sofia\AppData\Local\Temp\ipykernel_13532\1285667090.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['type'] = pd.Categorical(df['type'], categories=order, ordered=True)
# C:\Users\sofia\AppData\Local\Temp\ipykernel_13532\1285667090.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='type', y='spotify_popularity', palette='winter')

# %%
# Distribuição de tipos de álbum
plt.figure(figsize=(10, 10))
sns.countplot(data=df, y='type', palette='winter', order=df['type'].value_counts().index)
plt.title('Distribuição de tipos de álbum', fontsize=20, weight = 'bold')
plt.xlabel('Número de álbuns no catálogo', fontsize=12)
plt.ylabel('Tipo', fontsize=12)
plt.yticks(rotation=0)
plt.show()
# Out:
# C:\Users\sofia\AppData\Local\Temp\ipykernel_13532\3625883081.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, y='type', palette='winter', order=df['type'].value_counts().index)

# %% [markdown]
# A partir do primeiro gráfico, somos levados a concluir que álbuns que não são de Studio não são tão populares, no entanto, a quantidade desses tipos de álbum no catálogo que é mostrada no gráfico de barras sugere que esses álbuns não representam uma parcela significativa do catálogo, sendo que pode ser interessante expandir o catálogo com esses tipos de álbum de modo a obter um acervo mais diversificado. Os álbuns de Soundtrack, por exemplo, apresentam uma popularidade alta quando comparada aos outros tipos, porém não representam uma quantidade significativa no acervo

# %%
# Quantidade de álbuns no acervo por ano de lançamento
albums_per_year = df.groupby('release_year').size().reset_index(name='album_count')

plt.figure(figsize=(10, 6))
sns.set(style="whitegrid") 
sns.lineplot(data=albums_per_year, x='release_year', y='album_count', palette='winter', linewidth=2.5)

plt.title('Quantidade de álbuns no acervo por ano de lançamento', fontsize=16, weight='bold')
plt.xlabel('Ano de Lançamento', fontsize=12)
plt.ylabel('Número de Álbuns', fontsize=12)
plt.show()
# Out:
# C:\Users\sofia\AppData\Local\Temp\ipykernel_13532\3615163088.py:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=albums_per_year, x='release_year', y='album_count', palette='winter', linewidth=2.5)

# %%
# Popularidade x Ano de Lançamento
plt.figure(figsize=(10, 6))
sns.set(style="whitegrid")  

sns.regplot(data=df, x='release_year', y='spotify_popularity', 
            scatter_kws={'color': sns.color_palette('winter', as_cmap=True)(0.7)}, 
            line_kws={"color": "red", "linewidth": 2})  
plt.title('Popularidade x Ano de Lançamento', fontsize=16, weight='bold')
plt.xlabel('Ano de Lançamento', fontsize=12)
plt.ylabel('Popularidade no Spotify', fontsize=12)

plt.show()
#o coeficiente linear da reta e aproximadamente 0.4

# %% [markdown]
# Ao buscar a relação entre as datas de lançamento do álbum e sua popularidade no Spotify no primeiro. Contudo, o segundo gráfico mostra que a base de dados da loja carece de álbuns lançados recentemente, o que pode ser um motor para o baixo desempenho lamentado no inicio do projeto

# %%
# Idade média dos artistas x Popularidade no Spotify
plt.figure(figsize=(10, 6))
sns.regplot(data=df, x='ave_age', y='spotify_popularity', 
            scatter_kws={'color': sns.color_palette('winter', as_cmap=True)(0.7)},  
            line_kws={"color": "red", "linewidth": 2}) 


plt.title('Idade média dos artistas x Popularidade no Spotify', fontsize=16, weight='bold')
plt.xlabel('Idade', fontsize=12)
plt.ylabel('Popularidade', fontsize=12)


plt.show()

# %% [markdown]
# Utilizando um gráfico de dispersão, entre idade de artistas e popularidade no Spotify, percebe-se que artistas jovens tendem a ser mais populares.

# %%
# Idade média dos artistas por gênero musical
df_sorted = df.groupby('genre')['ave_age'].mean().reset_index().sort_values(by='ave_age', ascending=True)
plt.figure(figsize=(12, 6))
sns.barplot(data=df_sorted, x='genre', y='ave_age', palette='winter')
plt.title('Idade média dos artistas por gênero musical', fontsize = 20, weight='bold')
plt.xlabel('Gênero musical')
plt.ylabel('Idade média')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\sofia\AppData\Local\Temp\ipykernel_13532\472625148.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_sorted, x='genre', y='ave_age', palette='winter')

# %% [markdown]
# É possível observar que os gêneros que foram identificados anteriormente como os mais populares estão também entre os com artistas mais jovens. Corroborando com a premissa de que a idade é um fator importante a ser considerando na priorização dos álbuns.

# %%
# LISTA DOS 50 ÁLBUNS MAIS POPLARES 
top_50_albums = df.nlargest(50, 'spotify_popularity')
pd.set_option('display.max_rows', 700)
display(top_50_albums[['clean_name', 'album','genre', 'spotify_popularity','weeks_on_billboard']])
# Out:
#               clean_name                                    album  \
# 347       Arctic Monkeys                                       AM
# 245           Kanye West                               Graduation
# 447         Harry Styles                                Fine Line
# 684               Eminem                          The Eminem Show
# 69         Billie EIlish  When We All Fall Asleep Where Do We Go?
# 155          Frank Ocean                                   Blonde
# 104           Kanye West        My Beautiful Dark Twisted Fantasy
# 223       Kendrick Lamar                                     DAMN
# 415           The Weeknd                Beauty Behind the Madness
# 60          Lana Del Ray                  Norman Fucking Rockwell
# 166                Drake                                Take Care
# 202          Frank Ocean                           Channel Orange
# 377          Tame Impala                                 Currents
# ...

# %% [markdown]
# Composta majoritariamente por gêneros previamente identificados como os que possuem maior potencial de venda

# %%
df.describe()
# Out:
#         rank_2003   rank_2012   rank_2020  differential  release_year  \
# count  494.000000  493.000000  498.000000    684.000000    684.000000
# mean   249.961538  249.661258  249.694779    -10.789474   1982.874269
# std    145.085246  145.091774  144.180677    199.298843     14.533809
# min      1.000000    1.000000    1.000000   -501.000000   1955.000000
# 25%    124.250000  124.000000  125.250000   -135.250000   1971.000000
# 50%    248.500000  248.000000  249.500000     -7.000000   1979.000000
# 75%    375.750000  375.000000  373.750000    107.250000   1994.000000
# max    500.000000  500.000000  500.000000    484.000000   2019.000000
#
#        weeks_on_billboard  peak_billboard_position  spotify_popularity  \
# count          684.000000               684.000000          651.000000
# mean            53.747076                60.323099           55.849462
# std             72.710514                76.565722           14.931394
# ...

# %%
# Popularidade no Spotify x Semanas na Billboard 200
Q1 = df_weeks['weeks_on_billboard'].quantile(0.25)
Q3 = df_weeks['weeks_on_billboard'].quantile(0.75)
IQR = Q3 - Q1

df_sem_outliers = df_weeks[~((df_weeks['weeks_on_billboard'] < (Q1 - 1.5 * IQR)) | (df_weeks['weeks_on_billboard'] > (Q3 + 1.5 * IQR)))]

plt.figure(figsize=(10, 6))
sns.regplot(data=df_sem_outliers, 
            x='weeks_on_billboard', 
            y='spotify_popularity', 
            scatter_kws={'color': 'blue', 'alpha': 0.5},  # Ajuste de transparência
            line_kws={'color': 'red'})
plt.title('Popularidade no Spotify x Semanas na Billboard 200', fontsize=16, weight='bold')
plt.xlabel('Semanas na Billboard 200', fontsize=12)
plt.ylabel('Popularidade no Spotify', fontsize=12)

plt.show()

# %%
# Outliers retirados 
# Cálculo: 75 + ((75-9,75)*1,5) = 172,875

albums_over_172_weeks = df[df['weeks_on_billboard'] > 172].shape[0]

print(f"Número de álbuns com mais de 172 semanas na Billboard: {albums_over_172_weeks}")
# Out:
# Número de álbuns com mais de 172 semanas na Billboard: 32

# %%
# Média de Semanas na Billboard por Gênero
genre_stats = df_weeks.groupby('genre').agg({
    'weeks_on_billboard': 'mean',
    'peak_billboard_position': 'mean'
}).reset_index()

ordered_genres_weeks = genre_stats.sort_values('weeks_on_billboard')['genre'].tolist()

plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='genre', y='weeks_on_billboard', palette='winter', order=ordered_genres_weeks)
plt.title('Boxplot da Média de Semanas na Billboard por Gênero', fontsize=16, weight='bold')
plt.xlabel('Gênero', fontsize=12)
plt.ylabel('Média de Semanas na Billboard', fontsize=12)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\sofia\AppData\Local\Temp\ipykernel_13532\2858184300.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='genre', y='weeks_on_billboard', palette='winter', order=ordered_genres_weeks)

# %% [markdown]
# A Billboard 200 é uma lista que classifica os 200 álbuns mais vendidos naquela semana, percebe-se então, que quanto mais popular é o álbum no Spotify, mais tempo ele vende bem, sendo essa uma métrica relevante se o objetivo é elevar as vendas da Melodia Records

# %%
# Média no ranking da Rolling Stone de 2020 por faixa etária dos artistas (Top 100)

df_100 = df_rank_2020[df_rank_2020['rank_2020'] <= 100]

df_100['age_group'] = pd.cut(df_100['ave_age'], 
                                  bins=[0, 30, 40, 50, 60, 70, 80, 100], 
                                  right=False, 
                                  labels=['0-29', '30-39', '40-49', '50-59', '60-69', '70-79', '80+'])

age_rank_stats = df_100.groupby('age_group')['rank_2020'].mean().reset_index()

age_rank_stats = age_rank_stats.dropna()

plt.figure(figsize=(12, 6))
sns.barplot(data=age_rank_stats, x='age_group', y='rank_2020', palette='winter')

plt.gca().invert_yaxis()

plt.title('Média no ranking da Rolling Stone de 2020 por faixa etária dos artistas (Top 100)', fontsize=16, weight='bold')
plt.xlabel('Faixa Etária dos Artistas (Anos)', fontsize=12)
plt.ylabel('Média de Rank em 2020', fontsize=12)
plt.xticks(rotation=45, fontsize=10)

plt.show()
# Out:
# C:\Users\sofia\AppData\Local\Temp\ipykernel_13532\1943274966.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_100['age_group'] = pd.cut(df_100['ave_age'],
# C:\Users\sofia\AppData\Local\Temp\ipykernel_13532\1943274966.py:10: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_rank_stats = df_100.groupby('age_group')['rank_2020'].mean().reset_index()
# C:\Users\sofia\AppData\Local\Temp\ipykernel_13532\1943274966.py:15: FutureWarning:
#
# ...

# %%
# Popularidade de artistas solo e grupos musicais (não utilizado)

df['member_category'] = df['artist_member_count'].apply(lambda x: '2 ou mais membros' if x >= 2 else '1 membro')


plt.figure(figsize=(10, 6))

sns.boxplot(data=df, x='member_category', y='spotify_popularity', palette='winter')

plt.title('Popularidade de artistas solo e grupos musicais', fontsize=16, weight='bold')
plt.xlabel('Número de Membros', fontsize=12)
plt.ylabel('Popularidade no Spotify', fontsize=12)


plt.show()

# Não há uma diferença significante
# Out:
# C:\Users\sofia\AppData\Local\Temp\ipykernel_13532\3200772738.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['member_category'] = df['artist_member_count'].apply(lambda x: '2 ou mais membros' if x >= 2 else '1 membro')
# C:\Users\sofia\AppData\Local\Temp\ipykernel_13532\3200772738.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='member_category', y='spotify_popularity', palette='winter')

# %%
# Número de álbuns por gênero nos rankings dos anos 2003, 2012 e 2020 (não utilizado)
df_melted = pd.melt(df, id_vars=['genre'], 
                    value_vars=['rank_2003', 'rank_2012', 'rank_2020'], 
                    var_name='year', value_name='rank')
df_melted = df_melted.dropna(subset=['rank'])
plt.figure(figsize=(12, 6))
sns.countplot(data=df_melted, x='genre', hue='year', palette='winter')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Gênero')
plt.ylabel('Número de álbuns no ranking')
plt.title('Número de álbuns por gênero nos rankings dos anos 2003, 2012 e 2020')
plt.show()

# %%
# Popularidade no Spotify x Crescimento no ranking da Rolling Stone (não utilizado)
plt.figure(figsize=(10, 6))
sns.regplot(data=df_diff, x='differential', y='spotify_popularity', scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
plt.title('Popularidade no Spotify x Crescimento no ranking da Rolling Stone')
plt.xlabel('Diferença entre as posições de 2003 e 2020')
plt.ylabel('Popularidade no Spotify')
plt.show()

# %%
# Popularidade no Spotify x Ranking (não utilizado)
plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
sns.regplot(data=df_rank_2003, x='rank_2003', y='spotify_popularity', scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})

plt.xlabel('Rank 2003')
plt.ylabel('Popularidade no Spotify')
plt.subplot(1, 3, 2)
sns.regplot(data=df_rank_2012, x='rank_2012', y='spotify_popularity', scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
plt.title('Popularidade no Spotify em relação à posição no ranking dos anos 2003, 2012 e 2020')
plt.xlabel('Rank 2012')
plt.ylabel('Popularidade no Spotify')
plt.subplot(1, 3, 3)
sns.regplot(data=df_rank_2020, x='rank_2020', y='spotify_popularity', scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})

plt.xlabel('Rank 2020')
plt.ylabel('Popularidade no Spotify')
plt.tight_layout()
plt.show()

#pouco relacionados

# %%
# Popularidade no Spotify por Gênero do Artista (não utilizado)
plt.figure(figsize=(12, 6))

sns.boxplot(data=df, x='artist_gender', y='spotify_popularity', palette='winter')  # Paleta cividis

plt.title('Popularidade no Spotify por Gênero do Artista', fontsize=16, weight='bold')
plt.xlabel('Gênero do Artista', fontsize=12)
plt.ylabel('Popularidade no Spotify', fontsize=12)

plt.xticks(rotation=45)

plt.show()
# Out:
# C:\Users\sofia\AppData\Local\Temp\ipykernel_13532\2074759483.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='artist_gender', y='spotify_popularity', palette='winter')  # Paleta cividis

# %%
# Posição mais alta na Billboard x semanas na billboard (não utilizado)

plt.figure(figsize=(12, 6))
sns.scatterplot(data=df_weeks, x='peak_billboard_position', y='weeks_on_billboard', alpha=0.6, s=100)
plt.title('peak_billboard_position x weeks_on_billboard')
plt.xlabel('Posição no auge')
plt.ylabel('Semanas na Billboard 200')
plt.grid()
plt.show()

# %%
# Média de Ranks por Gênero (2003, 2012, 2020) (não utilizado)
mean_ranks = df.groupby('genre')[['rank_2003', 'rank_2012', 'rank_2020']].mean().reset_index()
plt.figure(figsize=(12, 6))
plt.plot(mean_ranks['genre'], mean_ranks['rank_2003'], marker='o', label='Rank 2003')
plt.plot(mean_ranks['genre'], mean_ranks['rank_2012'], marker='o', label='Rank 2012')
plt.plot(mean_ranks['genre'], mean_ranks['rank_2020'], marker='o', label='Rank 2020')
plt.title('Média de Ranks por Gênero (2003, 2012, 2020)')
plt.xlabel('Gênero')
plt.ylabel('Média do Rank')
plt.xticks(rotation=90)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Gráfico não utilizado, preferimos o boxplot
mean_popularity = df.groupby('genre')['spotify_popularity'].mean().reset_index()
mean_popularity = mean_popularity.sort_values(by='spotify_popularity', ascending=False)


plt.figure(figsize=(12, 6))
sns.barplot(data=mean_popularity, y='genre', x='spotify_popularity', palette='winter')

plt.title('Média de popularidade no spotify por gênero', fontsize=16, weight='bold')
plt.ylabel('Gênero', fontsize=12)
plt.xlabel('Média de Popularidade', fontsize=12)

plt.show()
# Out:
# C:\Users\sofia\AppData\Local\Temp\ipykernel_13532\2773687091.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=mean_popularity, y='genre', x='spotify_popularity', palette='winter')
